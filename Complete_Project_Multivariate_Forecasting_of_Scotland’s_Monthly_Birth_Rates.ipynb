# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df =pd.read_csv("/content/final_merged_dataset.csv")

# %%
df
# Out:
#      Year Month Births  cpi index  UnemploymentRate  Maternities  Live Births  \
# 0    1954   Jan  7,716        NaN               NaN          NaN          NaN
# 1    1955   Jan  7,849        NaN               NaN          NaN          NaN
# 2    1956   Jan  8,223        NaN               NaN          NaN          NaN
# 3    1957   Jan  8,476        NaN               NaN          NaN          NaN
# 4    1958   Jan  8,642        NaN               NaN          NaN          NaN
# ..    ...   ...    ...        ...               ...          ...          ...
# 859  2021   Dec  3,488    115.051               4.6      47113.0      47571.0
# 860  2022   Dec  3,072    127.164               3.8      44714.0      45217.0
# 861  2023   Dec  3,059    132.242               4.1          NaN          NaN
# 862  2020   Dec    NaN    109.171               4.6      45715.0      46188.0
# 863  2024   Dec    NaN    135.552               4.3          NaN          NaN
#
# ...

# %%
df.head()
# Out:
#    Year Month Births  cpi index  UnemploymentRate  Maternities  Live Births  \
# 0  1954   Jan  7,716        NaN               NaN          NaN          NaN
# 1  1955   Jan  7,849        NaN               NaN          NaN          NaN
# 2  1956   Jan  8,223        NaN               NaN          NaN          NaN
# 3  1957   Jan  8,476        NaN               NaN          NaN          NaN
# 4  1958   Jan  8,642        NaN               NaN          NaN          NaN
#
#    BMI (Obesity %)  Diabetes %  Induction %  Method of Birth  Preterm%  \
# 0              NaN         NaN          NaN              NaN       NaN
# 1              NaN         NaN          NaN              NaN       NaN
# 2              NaN         NaN          NaN              NaN       NaN
# 3              NaN         NaN          NaN              NaN       NaN
# 4              NaN         NaN          NaN              NaN       NaN
#
#    FulltTerm%  Neonatal mortality %  SGA%  AGA%  LGA%  Unnamed: 1  total  \
# ...

# %%
df.tail()
# Out:
#      Year Month Births  cpi index  UnemploymentRate  Maternities  Live Births  \
# 859  2021   Dec  3,488    115.051               4.6      47113.0      47571.0
# 860  2022   Dec  3,072    127.164               3.8      44714.0      45217.0
# 861  2023   Dec  3,059    132.242               4.1          NaN          NaN
# 862  2020   Dec    NaN    109.171               4.6      45715.0      46188.0
# 863  2024   Dec    NaN    135.552               4.3          NaN          NaN
#
#      BMI (Obesity %)  Diabetes %  Induction %  Method of Birth  Preterm%  \
# 859        27.221082    7.944603    34.350083             37.5       8.1
# 860        27.918132    8.144105    35.211647             39.2       8.4
# 861              NaN         NaN          NaN              NaN       NaN
# 862        25.910000    6.308390    34.375450             36.0       8.1
# 863              NaN         NaN          NaN              NaN       NaN
#
# ...

# %%
df.describe()
# Out:
#               Year   cpi index  UnemploymentRate   Maternities   Live Births  \
# count   864.000000  336.000000        660.000000    168.000000    168.000000
# mean   1989.430556   94.195429          6.612727  51387.785714  51944.071429
# std      20.683899   17.640071          2.360066   4314.809243   4364.528963
# min    1954.000000   70.254000          3.700000  44714.000000  45217.000000
# 25%    1971.750000   77.163750          4.600000  47113.000000  47571.000000
# 50%    1989.500000   94.846500          5.600000  52230.000000  52790.500000
# 75%    2007.250000  106.852750          8.100000  54725.000000  55365.000000
# max    2024.000000  135.552000         11.800000  57371.000000  57952.000000
#
#        BMI (Obesity %)  Diabetes %  Induction %  Method of Birth    Preterm%  \
# count       168.000000  168.000000   168.000000       168.000000  168.000000
# mean         23.839523    4.283435    31.525115        32.364286    7.935714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 864 entries, 0 to 863
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  864 non-null    int64
#  1   Month                 864 non-null    object
#  2   Births                840 non-null    object
#  3   cpi index             336 non-null    float64
#  4   UnemploymentRate      660 non-null    float64
#  5   Maternities           168 non-null    float64
#  6   Live Births           168 non-null    float64
#  7   BMI (Obesity %)       168 non-null    float64
#  8   Diabetes %            168 non-null    float64
#  9   Induction %           168 non-null    float64
#  10  Method of Birth       168 non-null    float64
#  11  Preterm%              168 non-null    float64
#  12  FulltTerm%            168 non-null    float64
#  13  Neonatal mortality %  168 non-null    float64
# ...

# %%
df.shape
# Out:
# (864, 20)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Births', 'cpi index', 'UnemploymentRate',
#        'Maternities', 'Live Births', 'BMI (Obesity %)', 'Diabetes %',
#        'Induction %', 'Method of Birth', 'Preterm%', 'FulltTerm%',
#        'Neonatal mortality %', 'SGA%', 'AGA%', 'LGA%', 'Unnamed: 1', 'total',
#        'female%'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Year                      int64
# Month                    object
# Births                   object
# cpi index               float64
# UnemploymentRate        float64
# Maternities             float64
# Live Births             float64
# BMI (Obesity %)         float64
# Diabetes %              float64
# Induction %             float64
# Method of Birth         float64
# Preterm%                float64
# FulltTerm%              float64
# Neonatal mortality %    float64
# SGA%                    float64
# AGA%                    float64
# LGA%                    float64
# Unnamed: 1              float64
# total                   float64
# female%                 float64
# dtype: object

# %%
df['Births'] = df['Births'].str.replace(',', '').astype(float)

# %%
df.dtypes
# Out:
# Year                      int64
# Month                    object
# Births                  float64
# cpi index               float64
# UnemploymentRate        float64
# Maternities             float64
# Live Births             float64
# BMI (Obesity %)         float64
# Diabetes %              float64
# Induction %             float64
# Method of Birth         float64
# Preterm%                float64
# FulltTerm%              float64
# Neonatal mortality %    float64
# SGA%                    float64
# AGA%                    float64
# LGA%                    float64
# Unnamed: 1              float64
# total                   float64
# female%                 float64
# dtype: object

# %%
df["Date"]=pd.to_datetime(df["Year"].astype("str") + " - " + df["Month"])
df.set_index('Date' , inplace=True)
df = df.sort_index()
df.drop(['Year' ,'Month'] , axis=1 , inplace=True)

# %%
df.isnull().sum()
# Out:
# Births                   24
# cpi index               528
# UnemploymentRate        204
# Maternities             696
# Live Births             696
# BMI (Obesity %)         696
# Diabetes %              696
# Induction %             696
# Method of Birth         696
# Preterm%                696
# FulltTerm%              696
# Neonatal mortality %    696
# SGA%                    696
# AGA%                    696
# LGA%                    696
# Unnamed: 1              864
# total                   552
# female%                 552
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(10)

# %%
df.interpolate(method='linear', inplace=True)
df.fillna(method='ffill', inplace=True)
df.fillna(method='bfill', inplace=True)

# %%
df.drop(columns='Unnamed: 1', inplace =True)

# %%
df.isnull().sum()
# Out:
# Births                  0
# cpi index               0
# UnemploymentRate        0
# Maternities             0
# Live Births             0
# BMI (Obesity %)         0
# Diabetes %              0
# Induction %             0
# Method of Birth         0
# Preterm%                0
# FulltTerm%              0
# Neonatal mortality %    0
# SGA%                    0
# AGA%                    0
# LGA%                    0
# total                   0
# female%                 0
# dtype: int64

# %%
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6, 2))
    sns.boxplot(data=df[col])
    plt.title(f'Boxplot of {col} (Before Handling Outliers)')
    plt.show()

# %%
df.plot(figsize=(16, 10), subplots=True, title="Monthly Time Series")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

result = seasonal_decompose(df['Births'].dropna(), model='additive', period=12)
result.plot()
plt.suptitle('Seasonal Decomposition of Monthly Births', fontsize=16)
plt.tight_layout()
plt.show()

# %%
df.boxplot(figsize=(12, 6), showfliers=True)
plt.yscale("log")
plt.title("Boxplot with Log Scale")
plt.show()

# %%
for col in df.select_dtypes(include=np.number).columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    median = df[col].median()

    # Replace outliers with median
    df[col] = np.where((df[col] < lower) | (df[col] > upper), median, df[col])

# %%
print(df.shape)
df.describe()
# Out:
# (864, 17)
#             Births   cpi index  UnemploymentRate  Maternities  Live Births  \
# count   864.000000  864.000000        864.000000        864.0        864.0
# mean   5756.074074   73.901782          6.019444      57041.0      57696.0
# std    1520.971404    8.116461          2.322362          0.0          0.0
# min    2741.000000   70.254000          3.700000      57041.0      57696.0
# 25%    4665.500000   70.254000          4.100000      57041.0      57696.0
# 50%    5332.750000   70.254000          5.150000      57041.0      57696.0
# 75%    6828.000000   71.459000          7.600000      57041.0      57696.0
# max    9477.000000  101.138000         11.800000      57041.0      57696.0
#
#        BMI (Obesity %)  Diabetes %   Induction %  Method of Birth  \
# count     8.640000e+02  864.000000  8.640000e+02            864.0
# mean      2.073645e+01    1.095332  2.384176e+01             26.5
# std       1.670743e-13    0.000000  3.163747e-13              0.0
# ...

# %%
for col in df.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(6, 2))
    sns.boxplot(data=df[col])
    plt.title(f'Boxplot of {col} (After Handling Outliers)')
    plt.show()

# %%
lag_features = ['Births', 'cpi index', 'UnemploymentRate', 'Maternities', 'Live Births',
                'BMI (Obesity %)', 'Diabetes %', 'Induction %', 'Method of Birth',
                'Preterm%', 'FulltTerm%', 'Neonatal mortality %', 'SGA%', 'AGA%',
                'LGA%', 'total', 'female%']

for col in lag_features:
    df[f'{col}_lag1'] = df[col].shift(1)
    df[f'{col}_lag3'] = df[col].shift(3)
    df[f'{col}_lag6'] = df[col].shift(6)
df.dropna(inplace=True)

display(df.head())
display(df.tail())
# Out:
#             Births  cpi index  UnemploymentRate  Maternities  Live Births  \
# Date
# 1954-07-01  8173.0     70.254               4.1      57041.0      57696.0
# 1954-08-01  7557.0     70.254               4.1      57041.0      57696.0
# 1954-09-01  7093.0     70.254               4.1      57041.0      57696.0
# 1954-10-01  7532.0     70.254               4.1      57041.0      57696.0
# 1954-11-01  6925.0     70.254               4.1      57041.0      57696.0
#
#             BMI (Obesity %)  Diabetes %  Induction %  Method of Birth  \
# Date
# 1954-07-01         20.73645    1.095332    23.841765             26.5
# 1954-08-01         20.73645    1.095332    23.841765             26.5
# 1954-09-01         20.73645    1.095332    23.841765             26.5
# 1954-10-01         20.73645    1.095332    23.841765             26.5
# 1954-11-01         20.73645    1.095332    23.841765             26.5
#
#             Preterm%  ...  AGA%_lag6  LGA%_lag1  LGA%_lag3  LGA%_lag6  \
# ...

# %%
rolling_features = df.select_dtypes(include=np.number).columns.tolist()

for col in rolling_features:
    df[f'{col}_rolling_mean_3'] = df[col].rolling(window=3).mean()
    df[f'{col}_rolling_std_3'] = df[col].rolling(window=3).std()
display(df.head())
display(df.tail())
# Out:
#             Births  cpi index  UnemploymentRate  Maternities  Live Births  \
# Date
# 1954-07-01  8173.0     70.254               4.1      57041.0      57696.0
# 1954-08-01  7557.0     70.254               4.1      57041.0      57696.0
# 1954-09-01  7093.0     70.254               4.1      57041.0      57696.0
# 1954-10-01  7532.0     70.254               4.1      57041.0      57696.0
# 1954-11-01  6925.0     70.254               4.1      57041.0      57696.0
#
#             BMI (Obesity %)  Diabetes %  Induction %  Method of Birth  \
# Date
# 1954-07-01         20.73645    1.095332    23.841765             26.5
# 1954-08-01         20.73645    1.095332    23.841765             26.5
# 1954-09-01         20.73645    1.095332    23.841765             26.5
# 1954-10-01         20.73645    1.095332    23.841765             26.5
# 1954-11-01         20.73645    1.095332    23.841765             26.5
#
#             Preterm%  ...  total_lag3_rolling_mean_3  \
# Date                  ...
# ...

# %%
df['month'] = df.index.month
df = pd.get_dummies(df, columns=['month'], prefix='month')
display(df.head())
display(df.tail())
# Out:
#             Births  cpi index  UnemploymentRate  Maternities  Live Births  \
# Date
# 1954-07-01  8173.0     70.254               4.1      57041.0      57696.0
# 1954-08-01  7557.0     70.254               4.1      57041.0      57696.0
# 1954-09-01  7093.0     70.254               4.1      57041.0      57696.0
# 1954-10-01  7532.0     70.254               4.1      57041.0      57696.0
# 1954-11-01  6925.0     70.254               4.1      57041.0      57696.0
#
#             BMI (Obesity %)  Diabetes %  Induction %  Method of Birth  \
# Date
# 1954-07-01         20.73645    1.095332    23.841765             26.5
# 1954-08-01         20.73645    1.095332    23.841765             26.5
# 1954-09-01         20.73645    1.095332    23.841765             26.5
# 1954-10-01         20.73645    1.095332    23.841765             26.5
# 1954-11-01         20.73645    1.095332    23.841765             26.5
#
#             Preterm%  ...  month_3  month_4  month_5  month_6  month_7  \
# ...

# %% [markdown]
# **VAR MODEL**

# %%
import pandas as pd
from statsmodels.tsa.api import VAR
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# %%
data = df[['Births', 'UnemploymentRate']].copy()
data = data.dropna().sort_index()

# %%
data = data.loc[:, data.nunique() > 1]

# %%
train = data[:'2020-12-01']
test = data['2021-01-01':]

# %%
model = VAR(train)
var_model = model.fit(2)
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
forecast = var_model.forecast(train.values[-2:], steps=len(test))
forecast_df = pd.DataFrame(forecast, index=test.index, columns=data.columns)

# %%
y_true = test['Births']
var_pred = forecast_df['Births']

# %%
var_mae = mean_absolute_error(y_true, var_pred)
var_rmse = np.sqrt(mean_squared_error(y_true, var_pred))

# %%
print(f"VAR Model MAE: {var_mae:.2f}")
print(f"VAR Model RMSE: {var_rmse:.2f}")
# Out:
# VAR Model MAE: 955.92
# VAR Model RMSE: 1217.78

# %%
plt.figure(figsize=(6, 4))
plt.plot(y_true, label='Actual Births')
plt.plot(var_pred, label='Predicted Births', linestyle='--')
plt.title('VAR Model Forecast (Births)')
plt.xlabel('Date')
plt.ylabel('Births')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **RANDOM FOREST MODEL**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# %%
X = df.drop(columns=['Births'])
y = df['Births']

# %%
X_train = X[:'2020-12-01']
X_test = X['2021-01-01':]
y_train = y[:'2020-12-01']
y_test = y['2021-01-01':]

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict on test set
rf_pred = rf_model.predict(X_test)

# %%
ran_mae = mean_absolute_error(y_test, rf_pred)
ran_rmse = np.sqrt(mean_squared_error(y_test, rf_pred))

print(f"Random Forest MAE: {ran_mae:.2f}")
print(f"Random Forest RMSE: {ran_rmse:.2f}")
# Out:
# Random Forest MAE: 287.14
# Random Forest RMSE: 356.70

# %%
plt.figure(figsize=(6, 4))
plt.plot(y_test.index, y_test, label='Actual Births')
plt.plot(y_test.index, rf_pred, label='Predicted Births (RF)', linestyle='--')
plt.title('Random Forest Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Births')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **XGBOOST MODEL**

# %%
# !pip install xgboost

# %%
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
X = df.drop(columns=['Births'])
y = df['Births']

# %%
X_train = X[:'2020-12-01']
X_test = X['2021-01-01':]
y_train = y[:'2020-12-01']
y_test = y['2021-01-01':]

# %%
xgb_model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
 xgb_pred = xgb_model.predict(X_test)

# %%
xg_mae = mean_absolute_error(y_test,  xgb_pred)
xg_rmse = np.sqrt(mean_squared_error(y_test,  xgb_pred))

print(f"XGBoost MAE: {xg_mae:.2f}")
print(f"XGBoost RMSE: {xg_rmse:.2f}")
# Out:
# XGBoost MAE: 489.20
# XGBoost RMSE: 601.17

# %%
plt.figure(figsize=(6, 4))
plt.plot(y_test.index, y_test, label='Actual Births')
plt.plot(y_test.index,  xgb_pred, label='Predicted Births (XGBoost)', linestyle='--')
plt.title('XGBoost Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Births')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **LIGHTGBM MODEL**

# %%
# !pip install lightgbm

# %%
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# %%
X = df.drop(columns=['Births'])
y = df['Births']

# %%
X_train = X[:'2020-12-01']
X_test = X['2021-01-01':]
y_train = y[:'2020-12-01']
y_test = y['2021-01-01':]

# %%
lgb_model = lgb.LGBMRegressor(n_estimators=100, learning_rate=0.1, random_state=42)

# %%
lgb_model.fit(X_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000901 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4789
# [LightGBM] [Info] Number of data points in the train set: 810, number of used features: 71
# [LightGBM] [Info] Start training from score 5862.107407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
lgb_pred = lgb_model.predict(X_test)

# %%
light_mae = mean_absolute_error(y_test, lgb_pred)
light_rmse = np.sqrt(mean_squared_error(y_test, lgb_pred))

print(f"LightGBM MAE: {light_mae:.2f}")
print(f"LightGBM RMSE: {light_rmse:.2f}")
# Out:
# LightGBM MAE: 437.27
# LightGBM RMSE: 535.55

# %%
plt.figure(figsize=(6, 4))
plt.plot(y_test.index, y_test, label='Actual Births')
plt.plot(y_test.index, lgb_pred, label='Predicted Births (LightGBM)', linestyle='--')
plt.title('LightGBM Forecast vs Actual')
plt.xlabel('Date')
plt.ylabel('Births')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **LSTM MODEL**

# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
target_col = 'Births'
features = df.drop(columns=[target_col])
target = df[[target_col]]

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(features)
y_scaled = scaler_y.fit_transform(target)

# %%
scaled_df = np.hstack((X_scaled, y_scaled))

# %%
selected = ['Births', 'UnemploymentRate', 'cpi index']
data = df[selected].dropna().sort_index()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled = scaler.fit_transform(data)

# Function to create input sequences for LSTM
def create_sequences(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i, :-1])  # input features
        y.append(data[i, -1])  # target (Births)
    return np.array(X), np.array(y)

window_size = 6
X_seq, y_seq = create_sequences(scaled, window_size)

# %%
split = int(0.8 * len(X_seq))
X_train, X_test = X_seq[:split], X_seq[split:]
y_train, y_test = y_seq[:split], y_seq[split:]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential([
    LSTM(64, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=30, batch_size=16, verbose=1)
# Out:
# Epoch 1/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0289
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0294
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0242
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0211
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0213
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0237
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0196
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0232
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0210
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0212
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0200
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0196
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0170
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0181
# Epoch 15/30
# ...

# %%
y_pred = model.predict(X_test)

lstm_pred_orig = scaler.inverse_transform(np.concatenate((np.zeros((len(y_pred), 2)), y_pred), axis=1))[:, -1]
y_test_orig = scaler.inverse_transform(np.concatenate((np.zeros((len(y_test), 2)), y_test.reshape(-1,1)), axis=1))[:, -1]
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

lstm_mae = mean_absolute_error(y_test_orig,lstm_pred_orig)
lstm_rmse = np.sqrt(mean_squared_error(y_test_orig, lstm_pred_orig))
print(f"LSTM MAE: {lstm_mae:.2f}")
print(f"LSTM RMSE: {lstm_rmse:.2f}")

plt.figure(figsize=(6,4))
plt.plot(y_test_orig, label="Actual")
plt.plot(lstm_pred_orig, label="Predicted", linestyle="--")
plt.title("LSTM Forecast vs Actual")
plt.legend()
plt.show()
# Out:
# LSTM MAE: 12.31
# LSTM RMSE: 14.63

# %% [markdown]
# **GRU for Birth Forecasting**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np

# %%
gru_model = Sequential([
    GRU(64, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(1)
])

gru_model.compile(optimizer='adam', loss='mse')
gru_model.fit(X_train, y_train, epochs=30, batch_size=16, verbose=1)
# Out:
# Epoch 1/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0358
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0269
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0171
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0201
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0197
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0230
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0200
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0210
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0186
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0180
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0209
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0188
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0175
# Epoch 15/30
# ...

# %%
y_pred = gru_model.predict(X_test)


gru_pred_orig = scaler.inverse_transform(np.concatenate((np.zeros((len(y_pred), 2)), y_pred), axis=1))[:, -1]
y_test_orig = scaler.inverse_transform(np.concatenate((np.zeros((len(y_test), 2)), y_test.reshape(-1,1)), axis=1))[:, -1]
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step

# %%
gru_mae = mean_absolute_error(y_test_orig, gru_pred_orig)
gru_rmse = np.sqrt(mean_squared_error(y_test_orig, gru_pred_orig))
print(f"GRU MAE: {gru_mae:.2f}")
print(f"GRU RMSE: {gru_rmse:.2f}")

plt.figure(figsize=(6,4))
plt.plot(y_test_orig, label="Actual")
plt.plot(gru_pred_orig, label="Predicted (GRU)", linestyle="--")
plt.title("GRU Forecast vs Actual")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# GRU MAE: 11.12
# GRU RMSE: 13.57

# %%
# !pip install keras-tcn

# %%
from tcn import TCN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
tcn_model = Sequential([
    TCN(input_shape=(X_train.shape[1], X_train.shape[2])),  # TCN handles sequences
    Dense(1)
])

tcn_model.compile(optimizer='adam', loss='mse')
tcn_model.fit(X_train, y_train, epochs=30, batch_size=16, verbose=1)
# Out:
# Epoch 1/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - loss: 0.3592
# Epoch 2/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0240
# Epoch 3/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0196
# Epoch 4/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0225
# Epoch 5/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0228
# Epoch 6/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0191
# Epoch 7/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0218
# Epoch 8/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0159
# Epoch 9/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0254
# Epoch 10/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0168
# Epoch 11/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0205
# Epoch 12/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0157
# Epoch 13/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0290
# Epoch 14/30
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0147
# Epoch 15/30
# ...

# %%
y_pred = tcn_model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f2c403860c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step

# %%
tcn_pred_orig = scaler.inverse_transform(np.concatenate((np.zeros((len(y_pred), 2)), y_pred), axis=1))[:, -1]
y_test_orig = scaler.inverse_transform(np.concatenate((np.zeros((len(y_test), 2)), y_test.reshape(-1,1)), axis=1))[:, -1]

# %%
tcn_mae = mean_absolute_error(y_test_orig, tcn_pred_orig)
tcn_rmse = np.sqrt(mean_squared_error(y_test_orig,tcn_pred_orig))
print(f"TCN MAE: {tcn_mae:.2f}")
print(f"TCN RMSE: {tcn_rmse:.2f}")

plt.figure(figsize=(6,4))
plt.plot(y_test_orig, label="Actual")
plt.plot(tcn_pred_orig, label="Predicted (TCN)", linestyle="--")
plt.title("TCN Forecast vs Actual")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# TCN MAE: 11.78
# TCN RMSE: 14.15

# %%
# Store metrics for all models
results = {
    'Model': ['VAR', 'Random Forest', 'XGBoost', 'LightGBM', 'LSTM', 'GRU', 'TCN'],
    'MAE':   [var_mae, ran_mae, xg_mae, light_mae, lstm_mae, gru_mae, tcn_mae],
    'RMSE':  [var_rmse, ran_rmse, xg_rmse, light_rmse, lstm_rmse, gru_rmse, tcn_rmse]
}

import pandas as pd
results_df = pd.DataFrame(results)

# %%
results_df_sorted = results_df.sort_values(by='MAE')
print(" Model Performance Comparison (sorted by MAE):")
print(results_df_sorted)
# Out:
#  Model Performance Comparison (sorted by MAE):
#            Model         MAE         RMSE
# 5            GRU   11.118788    13.572998
# 6            TCN   11.782073    14.148065
# 4           LSTM   12.306154    14.626796
# 1  Random Forest  287.141458   356.702728
# 3       LightGBM  437.270904   535.552947
# 2        XGBoost  489.197286   601.174885
# 0            VAR  955.919654  1217.779802

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(results_df['Model'], results_df['MAE'], color='green', label='MAE')
plt.bar(results_df['Model'], results_df['RMSE'], alpha=0.6, color='orange', label='RMSE')
plt.title('Model Performance Comparison')
plt.ylabel('Error')
plt.legend()
plt.xticks(rotation=15)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# !pip install shap

# %%
import shap
import xgboost as xgb
import matplotlib.pyplot as plt
import pandas as pd

# %%
print("X_test shape:", X_test.shape)
# Out:
# X_test shape: (171, 6, 2)

# %%
X = df.drop(columns=['Births'])
y = df['Births']

X_train = X[:'2020-12-01']
X_test = X['2021-01-01':]

# %%
import shap


X_test_fixed = pd.DataFrame(X_test, columns=X.columns)

explainer = shap.Explainer(xgb_model)
shap_values = explainer(X_test_fixed)

shap.summary_plot(shap_values, X_test_fixed)

# %%
shap.dependence_plot("UnemploymentRate", shap_values.values, X_test)

# %%
shap.dependence_plot("Maternities", shap_values.values, X_test)

# %%
shap.dependence_plot("cpi index", shap_values.values, X_test)

# %%
shap.dependence_plot("BMI (Obesity %)", shap_values.values, X_test)

# %%
shap.plots.waterfall(shap_values[10])

# %%
X_test_early = X_test[:'2021-12']
X_test_late = X_test['2022-01':]

# %%
explainer = shap.Explainer(xgb_model)

shap_early = explainer(X_test_early)
shap_late = explainer(X_test_late)

# %%
plt.title("Feature Importance: 2021 (Pre-COVID/Post-Lockdown)")
shap.summary_plot(shap_early, X_test_early)

# %%
def get_mean_shap_values(shap_values, X):
    return pd.DataFrame(shap_values.values, columns=X.columns).abs().mean().sort_values(ascending=False)

early_importance = get_mean_shap_values(shap_early, X_test_early)
late_importance = get_mean_shap_values(shap_late, X_test_late)

# Combine into one DataFrame for comparison
compare_df = pd.DataFrame({
    '2021 Importance': early_importance,
    '2022 Importance': late_importance
})
compare_df['Change'] = compare_df['2022 Importance'] - compare_df['2021 Importance']
compare_df.sort_values('2022 Importance', ascending=False)
# Out:
#                                       2021 Importance  2022 Importance  \
# Births_rolling_mean_3                     1966.133179      1996.779053
# Births_lag1                                103.796051       114.555908
# Births_lag3                                 94.393898        91.309052
# Births_lag1_rolling_mean_3                  83.807159        83.237366
# Births_lag6                                 62.254818        79.357269
# ...                                               ...              ...
# UnemploymentRate_lag1_rolling_mean_3         0.000000         0.000000
# SGA%_lag6_rolling_mean_3                     0.000000         0.000000
# SGA%_rolling_std_3                           0.000000         0.000000
# female%_rolling_mean_3                       0.000000         0.000000
# total_lag1_rolling_mean_3                    0.000000         0.000000
#
#                                          Change
# Births_rolling_mean_3                 30.645874
# ...

# %%
pip install streamlit matplotlib pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 364.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
st.set_page_config(page_title="Birth Forecast Dashboard", layout="wide")
# Out:
# 2025-07-31 11:25:46.274 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
date_index = df['2021-01-01':].index[-len(y_test):]

# %%
print("date_index:", len(date_index))
print("y_test:", len(y_test))
print("rf_pred:", len(rf_pred))
# Out:
# date_index: 48
# y_test: 171
# rf_pred: 48

# %%
min_len = min(len(date_index), len(y_test), len(rf_pred), len(xgb_pred), len(lgb_pred),
              len(y_test_orig), len(lstm_pred_orig), len(gru_pred_orig), len(tcn_pred_orig))

model_results = {
    'VAR': pd.DataFrame({
        'date': y_true.index[-min_len:],
        'actual': y_true.values[-min_len:],
        'predicted': var_pred[-min_len:]
    }),
    'Random Forest': pd.DataFrame({
        'date': date_index[-min_len:],
        'actual': y_test[-min_len:],
        'predicted': rf_pred[-min_len:]
    }),
    'XGBoost': pd.DataFrame({
        'date': date_index[-min_len:],
        'actual': y_test[-min_len:],
        'predicted': xgb_pred[-min_len:]
    }),
    'LightGBM': pd.DataFrame({
        'date': date_index[-min_len:],
        'actual': y_test[-min_len:],
        'predicted': lgb_pred[-min_len:]
    }),
    'LSTM': pd.DataFrame({
        'date': date_index[-min_len:],
        'actual': y_test_orig[-min_len:],
        'predicted': lstm_pred_orig[-min_len:]
    }),
    'GRU': pd.DataFrame({
        'date': date_index[-min_len:],
        'actual': y_test_orig[-min_len:],
        'predicted': gru_pred_orig[-min_len:]
    }),
    'TCN': pd.DataFrame({
        'date': date_index[-min_len:],
        'actual': y_test_orig[-min_len:],
        'predicted': tcn_pred_orig[-min_len:]
    }),
}

# %%
with open("model_results.pkl", "wb") as f:
    pickle.dump(model_results, f)

# %%
from google.colab import files
files.download("model_results.pkl")

# %%
pip install streamlit

# %%
import streamlit as st

# %%
with open("model_results.pkl", "rb") as f:
    model_results = pickle.load(f)

# %%
st.set_page_config(page_title="Scotland Birth Forecast", layout="wide")
st.title("📈 Scotland Monthly Birth Forecast Dashboard")
# Out:
# 2025-07-31 12:02:36.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:02:36.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:02:36.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:02:36.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
with open("model_results.pkl", "rb") as f:
    model_results = pickle.load(f)

# %%
model_choice = st.selectbox("Choose a Forecasting Model", list(model_results.keys()))
selected_df = model_results[model_choice]

# Plot
st.subheader(f"📊 Actual vs Predicted Births – {model_choice}")
fig, ax = plt.subplots(figsize=(12, 5))
ax.plot(selected_df['date'], selected_df['actual'], label='Actual', linewidth=2)
ax.plot(selected_df['date'], selected_df['predicted'], label='Predicted', linestyle='--')
ax.set_xlabel("Date")
ax.set_ylabel("Monthly Births")
ax.set_title(f"{model_choice} Forecast")
ax.legend()
ax.grid(True)
st.pyplot(fig)
# Out:
# 2025-07-31 12:03:07.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:07.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:07.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:07.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:07.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:07.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:07.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.subheader("📋 Forecast Data Table")
st.dataframe(selected_df)
# Out:
# 2025-07-31 12:03:22.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:22.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:22.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:22.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:22.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:22.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
csv = selected_df.to_csv(index=False).encode('utf-8')
st.download_button("📥 Download CSV", csv, f"{model_choice}_forecast.csv", "text/csv")
# Out:
# 2025-07-31 12:03:37.379 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:37.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:37.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:37.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:37.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:37.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-31 12:03:37.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# False

# %%
code = '''<PASTE THE FULL app.py CODE HERE AS STRING>'''
with open("app.py", "w") as f:
    f.write(code)

# %%
from google.colab import files
files.download("app.py")

# %%
with open("requirements.txt", "w") as f:
    f.write("""streamlit
pandas
matplotlib
scikit-learn
xgboost
shap
pickle-mixin""")

# %%
from google.colab import files
files.download("requirements.txt")
